# %% [markdown]
# # Projekt: Dyfuzja barwnika w żelu
# ## Szablon dla studentów
#
# Uzupełnij fragmenty oznaczone komentarzem `TODO`.
#
# Plik danych: `dyfuzja.csv`
# Czas pomiaru: t = 120 s

# %% [markdown]
# ### Model fizyczny
# Rozwiązanie równania dyfuzji dla punktowego źródła :
#
# $C(x, t) = \frac{A}{\sqrt{4 \pi D t}} exp(-\frac{x^2}{4Dt})$
#
# gdzie:
# - $A$: stała normalizacyjna
# - $D$: współczynnik dyfizji
#
# przyjmij: $\frac{A}{\sqrt{4 \pi D t}} = C_0$
#
# więc, $C_0$ oraz $D$ są parametrami dopasowania

# %% [markdown]
# ### Zadanie
# W doświadczeniu laboratoryjnym obserwowano dyfuzję barwnika w żelu agarowym. Po czasie $t = 120\,s$ zmierzono profil stężenia wzdłuż osi $x$.
#
# Twoim zadaniem jest:
# - zasymulować proces dyfuzji,
# - dopasować model do danych pomiarowych
# - wyznaczyć współczynnik dyfuzji $D$

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import pandas as pd

# === Część A: Wczytanie danych ===

# TODO: wczytaj dane z pliku dyfuzja.csv


# TODO: przypisz x i C
# x = ...
# C = ...

# TODO: narysuj wykres danych

# %%
# === Część B: Dopasowanie modelu ===

t = 120  # czas pomiaru w sekundach

def model(x, C0, D):
    # TODO: zdefiniuj funkcję modelu
    pass

# TODO: dopasuj model do danych curve_fit
# popt, pcov = curve_fit(...)

# TODO: wyświetl wyznaczone parametry C0 i D oraz niepewność D

# %%
# === Część C: Symulacja profili dla różnych czasów ===

# TODO: wykorzystaj wyznaczone D do symulacji profili dla t = 30,60,120,240 s

# %%
# === Część D: Interpretacja ===

# TODO: oblicz szerokość profilu sigma = sqrt(2 D t)
